# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm

# %% [markdown]
# ## Exploring the Data

# %%
pd.set_option("display.max_columns", 999)
pd.set_option("display.max_rows", 999)

# %%
df1 = pd.read_csv("../Datasets/Merged/3_migration_merge_clean_final.csv")

# %%
df1.head()
# Out:
#   Country Name Country Code                     Region         Income Group  \
# 0        Aruba          ABW  Latin America & Caribbean          High income
# 1  Afghanistan          AFG                 South Asia           Low income
# 2       Angola          AGO         Sub-Saharan Africa  Lower middle income
# 3      Albania          ALB      Europe & Central Asia  Upper middle income
# 4      Andorra          AND      Europe & Central Asia          High income
#
#    Net Migration 1962  Population 1962  MigrRatePopn1962  Net Migration 1967  \
# 0             -4323.0          56225.0         -0.076888             -4275.0
# 1            -20000.0        9351441.0         -0.002139            -20000.0
# 2           -296717.0        5608539.0         -0.052905           -587286.0
# 3               -99.0        1711319.0         -0.000058               -99.0
# 4                 NaN          15370.0               NaN                 NaN
#
# ...

# %%
df2 = pd.read_csv("../Datasets/Happiness/2017.csv")

# %%
df2.head()
# Out:
#        Country  Happiness.Rank  Happiness.Score  Whisker.high  Whisker.low  \
# 0       Norway               1            7.537      7.594445     7.479556
# 1      Denmark               2            7.522      7.581728     7.462272
# 2      Iceland               3            7.504      7.622030     7.385970
# 3  Switzerland               4            7.494      7.561772     7.426227
# 4      Finland               5            7.469      7.527542     7.410458
#
#    Economy..GDP.per.Capita.    Family  Health..Life.Expectancy.   Freedom  \
# 0                  1.616463  1.533524                  0.796667  0.635423
# 1                  1.482383  1.551122                  0.792566  0.626007
# 2                  1.480633  1.610574                  0.833552  0.627163
# 3                  1.564980  1.516912                  0.858131  0.620071
# 4                  1.443572  1.540247                  0.809158  0.617951
#
#    Generosity  Trust..Government.Corruption.  Dystopia.Residual
# ...

# %%
df_merge_col = pd.merge(df1, df2, left_on='Country Name', right_on='Country')
df_merge_col
# Out:
#                  Country Name Country Code                      Region  \
# 0                 Afghanistan          AFG                  South Asia
# 1                      Angola          AGO          Sub-Saharan Africa
# 2                     Albania          ALB       Europe & Central Asia
# 3        United Arab Emirates          ARE  Middle East & North Africa
# 4                   Argentina          ARG   Latin America & Caribbean
# 5                     Armenia          ARM       Europe & Central Asia
# 6                   Australia          AUS         East Asia & Pacific
# 7                     Austria          AUT       Europe & Central Asia
# 8                  Azerbaijan          AZE       Europe & Central Asia
# 9                     Burundi          BDI          Sub-Saharan Africa
# 10                    Belgium          BEL       Europe & Central Asia
# 11                      Benin          BEN          Sub-Saharan Africa
# ...

# %%
df_merge_col['Country Name'].unique()
# Out:
# array(['Afghanistan', 'Angola', 'Albania', 'United Arab Emirates',
#        'Argentina', 'Armenia', 'Australia', 'Austria', 'Azerbaijan',
#        'Burundi', 'Belgium', 'Benin', 'Burkina Faso', 'Bangladesh',
#        'Bulgaria', 'Bahrain', 'Bosnia and Herzegovina', 'Belarus',
#        'Belize', 'Bolivia', 'Brazil', 'Bhutan', 'Botswana',
#        'Central African Republic', 'Canada', 'Switzerland', 'Chile',
#        'China', 'Cameroon', 'Colombia', 'Costa Rica', 'Cyprus',
#        'Czech Republic', 'Germany', 'Denmark', 'Dominican Republic',
#        'Algeria', 'Ecuador', 'Spain', 'Estonia', 'Ethiopia', 'Finland',
#        'France', 'Gabon', 'United Kingdom', 'Georgia', 'Ghana', 'Guinea',
#        'Greece', 'Guatemala', 'Honduras', 'Croatia', 'Haiti', 'Hungary',
#        'Indonesia', 'India', 'Ireland', 'Iraq', 'Iceland', 'Israel',
#        'Italy', 'Jamaica', 'Jordan', 'Japan', 'Kazakhstan', 'Kenya',
#        'Cambodia', 'Kuwait', 'Lebanon', 'Liberia', 'Libya', 'Sri Lanka',
# ...

# %%
df_merge_col2 = pd.merge(df1, df2, left_on='Country Name', right_on='Country', how='outer')

# %%
df_merge_col2
# Out:
#                                           Country Name Country Code  \
# 0                                                Aruba          ABW
# 1                                          Afghanistan          AFG
# 2                                               Angola          AGO
# 3                                              Albania          ALB
# 4                                              Andorra          AND
# 5                                           Arab World          ARB
# 6                                 United Arab Emirates          ARE
# 7                                            Argentina          ARG
# 8                                              Armenia          ARM
# 9                                       American Samoa          ASM
# 10                                 Antigua and Barbuda          ATG
# 11                                           Australia          AUS
# 12                                             Austria          AUT
# ...

# %%
country_list1 = df_merge_col2['Country Name'].unique()

# %%
country_list2 = df_merge_col2['Country'].unique()

# %%
for i in country_list1:
    if i not in country_list2:
        print(i)
# Out:
# Aruba
# Andorra
# Arab World
# American Samoa
# Antigua and Barbuda
# Bahamas, The
# Bermuda
# Barbados
# Brunei Darussalam
# Central Europe and the Baltics
# Channel Islands
# Cote d'Ivoire
# Congo, Dem. Rep.
# Congo, Rep.
# Comoros
# Cabo Verde
# Caribbean small states
# Cuba
# Curacao
# Cayman Islands
# Djibouti
# Dominica
# East Asia & Pacific (excluding high income)
# Early-demographic dividend
# East Asia & Pacific
# Europe & Central Asia (excluding high income)
# Europe & Central Asia
# Egypt, Arab Rep.
# Euro area
# Eritrea
# European Union
# Fragile and conflict affected situations
# Fiji
# Faroe Islands
# Micronesia, Fed. Sts.
# Gibraltar
# Gambia, The
# Guinea-Bissau
# Equatorial Guinea
# Grenada
# Greenland
# Guam
# Guyana
# High income
# Hong Kong SAR, China
# Heavily indebted poor countries (HIPC)
# IBRD only
# IDA & IBRD total
# IDA total
# IDA blend
# IDA only
# Isle of Man
# Iran, Islamic Rep.
# Kyrgyz Republic
# Kiribati
# St. Kitts and Nevis
# Korea, Rep.
# ...

# %%
for i in country_list2:
    if i not in country_list1:
        print(i)
# Out:
# nan
# Taiwan Province of China
# Slovakia
# Russia
# South Korea
# North Cyprus
# Hong Kong S.A.R., China
# Venezuela
# Macedonia
# Kyrgyzstan
# Palestinian Territories
# Egypt
# Iran
# Congo (Brazzaville)
# Congo (Kinshasa)
# Ivory Coast
# Yemen
# Syria

# %%
df_merge_col2['Country Name'].sort_values()
# Out:
# 1                                            Afghanistan
# 3                                                Albania
# 58                                               Algeria
# 9                                         American Samoa
# 4                                                Andorra
# 2                                                 Angola
# 10                                   Antigua and Barbuda
# 5                                             Arab World
# 7                                              Argentina
# 8                                                Armenia
# 0                                                  Aruba
# 11                                             Australia
# 12                                               Austria
# 13                                            Azerbaijan
# 21                                          Bahamas, The
# 20                                               Bahrain
# ...

# %% [markdown]
# ## Renaming Countries to ensure match for all countries

# %%
df2 = df2.replace('Russia', 'Russian Federation').replace('Slovakia', 'Slovak Republic').replace('South Korea', 'Korea, Rep.')
df2 = df2.replace('Hong Kong S.A.R., China', 'Hong Kong SAR, China').replace('Venezuela', 'Venezuela, RB').replace('Kyrgyzstan', 'Kyrgyz Republic')
df2 = df2.replace('Egypt', 'Egypt, Arab Rep.').replace('Iran', 'Iran, Islamic Rep.').replace('Congo (Brazzaville)', 'Congo, Rep.')
df2 = df2.replace('Congo (Kinshasa)', 'Congo, Dem. Rep.').replace('Yemen', 'Yemen, Rep.').replace('Syria', 'Syrian Arab Republic')
df2 = df2.replace('Ivory Coast', "Cote d'Ivoire").replace('Macedonia', 'North Macedonia').replace('Palestinian Territories', 'West Bank and Gaza')

# %%
df_merge_col = pd.merge(df1, df2, left_on='Country Name', right_on='Country', how='outer')
df_merge_col
# Out:
#                                           Country Name Country Code  \
# 0                                                Aruba          ABW
# 1                                          Afghanistan          AFG
# 2                                               Angola          AGO
# 3                                              Albania          ALB
# 4                                              Andorra          AND
# 5                                           Arab World          ARB
# 6                                 United Arab Emirates          ARE
# 7                                            Argentina          ARG
# 8                                              Armenia          ARM
# 9                                       American Samoa          ASM
# 10                                 Antigua and Barbuda          ATG
# 11                                           Australia          AUS
# 12                                             Austria          AUT
# ...

# %%
country_list1 = df_merge_col['Country Name'].unique()

# %%
country_list2 = df_merge_col['Country'].unique()

# %%
df_merge_col.drop(index = 263).drop(index = 264)
# Out:
#                                           Country Name Country Code  \
# 0                                                Aruba          ABW
# 1                                          Afghanistan          AFG
# 2                                               Angola          AGO
# 3                                              Albania          ALB
# 4                                              Andorra          AND
# 5                                           Arab World          ARB
# 6                                 United Arab Emirates          ARE
# 7                                            Argentina          ARG
# 8                                              Armenia          ARM
# 9                                       American Samoa          ASM
# 10                                 Antigua and Barbuda          ATG
# 11                                           Australia          AUS
# 12                                             Austria          AUT
# ...

# %%
df_merge_col.to_csv('../Datasets/Merged/4_migration_hapiness_merge.csv')
